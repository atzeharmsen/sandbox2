    [50.12200, 34.01103],
    [54.29513, 33.49633],
    [58.46826, 32.94079],
    [62.64139, 32.23819],
    [66.81452, 31.41304],
    [70.98765, 30.59606],
    [74.71818, 29.91187],
    [79.71329, 28.87060],
    [83.88642, 28.09610],
    [86.73174, 27.56507],
]

a16 = [
    [-85.47311, 31.62409],
    [-81.21778, 32.55350],
    [-76.82651, 33.29871],
    [-72.79564, 33.88522],
    [-68.62251, 34.69729],
    [-64.44938, 35.65316],
    [-60.27625, 36.64170],
    [-56.10312, 37.63025],
    [-51.92999, 38.52892],
    [-47.75686, 39.37041],
    [-43.58373, 40.13837],
    [-39.41060, 40.96352],
    [-35.23747, 41.89488],
    [-31.06434, 42.76087],
    [-26.83702, 43.68989],
    [-22.33871, 44.29352],
    [-18.16558, 44.77881],
    [-13.99245, 44.99122],
    [-9.81932, 44.99939],
    [-5.64619, 45.00756],
    [-1.47306, 45.13828],
    [2.70007, 45.26900],
    [6.87320, 45.61213],
    [11.04633, 45.93075],
    [15.21946, 46.20035],
    [19.39259, 46.44545],
    [23.56572, 46.38009],
    [27.73885, 45.85875],
    [32.29136, 44.78044],
    [36.46449, 43.24289],
    [40.63762, 41.31482],
    [44.81075, 39.83609],
    [48.98388, 38.75768],
    [53.15701, 37.99789],
    [57.33014, 37.24627],
    [61.50327, 36.61719],
    [65.67640, 36.03714],
    [69.84953, 35.44891],
    [74.02266, 34.89337],
    [78.63839, 34.20205],
    [83.12767, 33.55352],
    [86.35236, 33.00206],
]

a18 = [
    [-84.93566, 38.39004],
    [-80.76253, 38.86388],
    [-76.88447, 39.29779],
    [-72.64389, 39.66229],
    [-68.24314, 40.24458],
    [-64.07001, 41.06973],
    [-59.89688, 42.25435],
    [-55.72375, 43.81478],
    [-51.55062, 45.62847],
    [-47.37749, 47.60556],
    [-43.20436, 49.63983],
    [-39.03123, 51.29013],
    [-34.85810, 52.56462],
    [-31.06434, 53.27720],
    [-27.46246, 53.56032],
    [-22.37664, 53.79744],
    [-18.16558, 53.65120],
    [-13.99245, 53.38977],
    [-9.81932, 52.98128],
    [-5.64619, 52.72801],
    [-1.47306, 52.57279],
    [2.70007, 52.59730],
    [6.87320, 53.03847],
    [11.04633, 53.49597],
    [15.21946, 53.90446],
    [19.39259, 54.24759],
    [23.56572, 54.45184],
    [27.29625, 54.57108],
    [33.01217, 54.07183],
    [37.22324, 53.23454],
    [41.39637, 51.70679],
    [45.37981, 49.72643],
    [48.79419, 47.71789],
    [51.82919, 45.78574],
    [55.43326, 44.10072],
    [59.60639, 42.78538],
    [63.77952, 42.01742],
    [67.95265, 41.58442],
    [72.09362, 41.22022],
    [76.45971, 40.72173],
    [80.47204, 40.36712],
    [84.64517, 39.90145],
    [87.11111, 39.78707],
]

# %%
import pandas as pd
tropopause_df = pd.DataFrame(atropo, columns=["latitude", "altitude"])
a02_df = pd.DataFrame(a02, columns=["latitude", "altitude"])
a04_df = pd.DataFrame(a04, columns=["latitude", "altitude"])
a06_df = pd.DataFrame(a06, columns=["latitude", "altitude"])
a08_df = pd.DataFrame(a08, columns=["latitude", "altitude"])
a10_df = pd.DataFrame(a10, columns=["latitude", "altitude"])
a12_df = pd.DataFrame(a12, columns=["latitude", "altitude"])
a14_df = pd.DataFrame(a14, columns=["latitude", "altitude"])
a16_df = pd.DataFrame(a16, columns=["latitude", "altitude"])
a18_df = pd.DataFrame(a18, columns=["latitude", "altitude"])

# Add a 'value' column to each one before concatenating
a02_df["value"] = 0.2
a04_df["value"] = 0.4
a06_df["value"] = 0.6
a08_df["value"] = 0.8
a10_df["value"] = 1.0
a12_df["value"] = 1.2
a14_df["value"] = 1.4
a16_df["value"] = 1.6
a18_df["value"] = 1.8

tropopause_df["source"] = "tropopause"
a02_df["source"] = "a02"
a04_df["source"] = "a04"
a06_df["source"] = "a06"
a08_df["source"] = "a08"
a10_df["source"] = "a10"
a12_df["source"] = "a12"
a14_df["source"] = "a14"
a16_df["source"] = "a16"
a18_df["source"] = "a18"

# Concatenate them
a_df = pd.concat([tropopause_df, a02_df,a04_df, a06_df, a08_df, a10_df,a12_df,a14_df, a16_df, a18_df], ignore_index=True)
print(a_df)


# verification the myhre plot is properly represented.
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load your background image
img = mpimg.imread(r"C:\Users\atzeh\OneDrive\Documenten\TU\MASTER\Thesis\myhre2a.png")  # or .jpg, .tif, etc.

# Create the plot
fig, ax = plt.subplots()

# Show the image as the background
ax.imshow(img, extent=[-87, 87, 0, 65], aspect='auto')  # adjust extent to match your data coordinates

# Plot your points (example from earlier)

ax.scatter(a_df[a_df["source"] == "tropopause"]["latitude"], a_df[a_df["source"] == "tropopause"]["altitude"], color="yellow", label="tropopause")
ax.scatter(a_df[a_df["source"] == "a02"]["latitude"], a_df[a_df["source"] == "a02"]["altitude"], color="purple", label="a02")
ax.scatter(a_df[a_df["source"] == "a04"]["latitude"], a_df[a_df["source"] == "a04"]["altitude"], color="blue", label="a04")
ax.scatter(a_df[a_df["source"] == "a06"]["latitude"], a_df[a_df["source"] == "a06"]["altitude"], color="green", label="a06")
ax.scatter(a_df[a_df["source"] == "a08"]["latitude"], a_df[a_df["source"] == "a08"]["altitude"], color="yellow", label="a08")
ax.scatter(a_df[a_df["source"] == "a10"]["latitude"], a_df[a_df["source"] == "a10"]["altitude"], color="orange", label="a10")
ax.scatter(a_df[a_df["source"] == "a12"]["latitude"], a_df[a_df["source"] == "a12"]["altitude"], color="red", label="a12")
ax.scatter(a_df[a_df["source"] == "a14"]["latitude"], a_df[a_df["source"] == "a14"]["altitude"], color="brown", label="a14")
ax.scatter(a_df[a_df["source"] == "a16"]["latitude"], a_df[a_df["source"] == "a16"]["altitude"], color="grey", label="a16")
ax.scatter(a_df[a_df["source"] == "a18"]["latitude"], a_df[a_df["source"] == "a18"]["altitude"], color="black", label="a18")

ax.set_xlim(-87, 87)
ax.set_ylim(0, 65)
ax.legend()
plt.show()
# Out:
#      latitude  altitude      source  value
# 0   -85.63312   8.86024  tropopause    NaN
# 1   -79.62440   8.87259  tropopause    NaN
# 2   -73.74408   8.88383  tropopause    NaN
# 3   -67.67407   8.87259  tropopause    NaN
# 4   -61.60407   8.87259  tropopause    NaN
# ..        ...       ...         ...    ...
# 403  72.09362  41.22022         a18    1.8
# 404  76.45971  40.72173         a18    1.8
# 405  80.47204  40.36712         a18    1.8
# 406  84.64517  39.90145         a18    1.8
# 407  87.11111  39.78707         a18    1.8
#
# [408 rows x 4 columns]

# %%
from openairclim.calc_swv import *

a_df = construct_myhre_2a_df()
a_df
# Out:
#      latitude  altitude    value      source
# 0   -85.63312   8860.24  0.00000  tropopause
# 1   -79.62440   8872.59  0.00000  tropopause
# 2   -73.74408   8883.83  0.00000  tropopause
# 3   -67.67407   8872.59  0.00000  tropopause
# 4   -61.60407   8872.59  0.00000  tropopause
# ..        ...       ...      ...         ...
# 405  80.47204  40367.12  0.00172         a18
# 406  84.64517  39901.45  0.00172         a18
# 407  87.11111  39787.07  0.00172         a18
# 408 -87.00000  60000.00  0.00172         NaN
# 409  87.00000  60000.00  0.00172         NaN
#
# [410 rows x 4 columns]

# %%
delta_h = 100.        # height increment in meters
delta_deg = 1.        # latitude increment
heights = np.arange(0, 60000 + delta_h, delta_h)  # 0 to 60 km
latitudes = np.arange(-85, 86, delta_deg)  # -85° to 85°
        
myhre_2a_df = construct_myhre_2a_df()
# myhre_grid_a = get_griddata(myhre_2a_df, heights, latitudes, plot_data=True)
myhre_2b_df = construct_myhre_2b_df()
# myhre_grid_b = get_griddata(myhre_2b_df, heights, latitudes, plot_data=True)
myhre_2c_df = construct_myhre_2c_df()
# myhre_grid_c = get_griddata(myhre_2c_df, heights, latitudes, plot_data=True)

mass_a_list =[]
mass_b_list =[]
mass_c_list =[]
for delta_h in [1000.,100.,1000.]:
    for delta_deg in [10., 1., 10.]:
        heights = np.arange(0, 60000 + delta_h, delta_h)  # 0 to 60 km
        latitudes = np.arange(-85, 86, delta_deg)  # -85° to 85°
        print('\n\nvalue for different grids:\n delta_h=', delta_h,'\n delta_deg=', delta_deg)
        mass_a = get_total_mass(myhre_2a_df, heights, latitudes, delta_h, delta_deg)/10**9
        mass_b = get_total_mass(myhre_2b_df, heights, latitudes, delta_h, delta_deg)
        mass_c = get_total_mass(myhre_2c_df, heights, latitudes, delta_h, delta_deg)
        mass_a_list = mass_a_list + [mass_a]
        mass_b_list = mass_b_list + [mass_b]
        mass_c_list = mass_c_list + [mass_c]
print('mass a: ',mass_a_list)
print('mass b: ',mass_b_list)
print('mass c: ',mass_c_list)
print('gridding is not the issue, but the c case gives significantly higher results...')
# Out:
# value for different grids:
#  delta_h= 1000.0
#  delta_deg= 10.0
# Total SWV mass is: 0.21983267835268833 Tg
# Total SWV mass is: 0.21364488596464484 Tg
# Total SWV mass is: 0.23337432559239935 Tg
#
#
# value for different grids:
#  delta_h= 1000.0
#  delta_deg= 1.0
# Total SWV mass is: 0.21784652966252568 Tg
# Total SWV mass is: 0.2115770075754233 Tg
# Total SWV mass is: 0.23223159144280855 Tg
#
#
# value for different grids:
#  delta_h= 1000.0
#  delta_deg= 10.0
# Total SWV mass is: 0.21983267835268833 Tg
# Total SWV mass is: 0.21364488596464484 Tg
# Total SWV mass is: 0.23337432559239935 Tg
#
#
# value for different grids:
#  delta_h= 100.0
#  delta_deg= 10.0
# Total SWV mass is: 0.21971589687312504 Tg
# Total SWV mass is: 0.21343497921250418 Tg
# Total SWV mass is: 0.23314932974077054 Tg
#
#
# value for different grids:
#  delta_h= 100.0
#  delta_deg= 1.0
# Total SWV mass is: 0.2177344470998827 Tg
# Total SWV mass is: 0.2114614595282279 Tg
# ...

# %%
# df_diff = myhre_2a_df
# df_diff['value'] = df_diff['value']-myhre_2c_df['value']
grid_diff = myhre_grid_c-myhre_grid_a
# display(grid_diff)
xi = latitudes
yi = heights/1000 #due to gridddata
X, Y = np.meshgrid(xi, yi)

plt.figure(figsize=(10, 6))
heatmap = plt.pcolormesh(X, Y, grid_diff, shading='auto', cmap='viridis')
plt.colorbar(heatmap, label='Value')

plt.xlabel('Latitude')
plt.ylabel('Altitude')
plt.title('SWV ppmv')
plt.tight_layout()
# plt.scatter(df[df["source"] == "b10"]["latitude"], df[df["source"] == "b10"]["altitude"]/1000, color="red",
#             label="b10") # /1000 due to griddata
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 # df_diff = myhre_2a_df
#       2 # df_diff['value'] = df_diff['value']-myhre_2c_df['value']
# ----> 3 grid_diff = myhre_grid_c-myhre_grid_a
#       4 # display(grid_diff)
#       5 xi = latitudes
#
# NameError: name 'myhre_grid_c' is not defined

# %%
p = r"C:\Users\atzeh\PycharmProjects\OAC_Thesis\repository\resp_ch4.nc"
import xarray as xr
data = xr.load_dataset(p)
data
# Out:
# <xarray.Dataset> Size: 3kB
# Dimensions:       (emi_lat: 16, emi_plev: 4)
# Coordinates:
#     time          datetime64[ns] 8B 2016-07-16T12:00:00
#   * emi_lat       (emi_lat) float32 64B -85.09 -75.34 -65.58 ... 55.81 65.58
#   * emi_plev      (emi_plev) float32 16B 100.0 218.0 523.0 991.0
# Data variables:
#     emi_loc       (emi_lat, emi_plev) <U7 2kB 'm85_100' 'm85_218' ... 'p65_991'
#     emi_air_mass  (emi_lat, emi_plev) float64 512B 2.664e+14 ... 7.937e+14
#     CH4           (emi_lat, emi_plev) float64 512B 5.681e-05 ... 5.698e-05
# Attributes:
#     Title:       Response: NO Emission --> inverse CH4 lifetime
#     resp_type:   tau
#     Convention:  CF-1.6
#     Author:      Hiroshi Yamashita (b309085), Stefan Völk
#     Note:        Response surface incomplete and not validated!

# %%
data['CH4'].T.plot()

# sec = 10*365
# 
# 1/sec
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 1/data['CH4'].T.plot()
#       3 # sec = 10*365
#       4 #
#       5 # 1/sec
#
# TypeError: unsupported operand type(s) for /: 'int' and 'QuadMesh'

# %%
1/0.0012
5000/365
# Out:
# 13.698630136986301

# %%
FRANK = [
    [0.2048, 0.03030],
    [0.01442, 0.03036],
    [0.04842, 0.03037],
    [0.08921, 0.03045],
    [0.1391, 0.03052],
    [0.1187, 0.03054],
    [0.1753, 0.03071],
    [0.2252, 0.03078],
    [0.3068, 0.03098],
    [0.3521, 0.03107],
    [0.2683, 0.03113],
    [0.3907, 0.03118],
    [0.6280, 0.03125],
    [0.4224, 0.03125],
    [0.4428, 0.03126],
    [0.4791, 0.03139],
    [1.557, 25.80],
    [1.539, 29.54],
    [1.521, 34.10],
    [1.505, 39.65],
    [1.496, 45.74],
    [1.492, 52.97],
    [1.490, 61.85],
    [1.499, 73.41],
    [1.528, 81.52],
    [1.564, 86.44],
    [1.587, 88.59],
    [1.614, 90.79],
    [1.651, 92.55],
    [1.691, 95.38],
    [1.721, 96.17],
    [1.741, 97.76],
    [1.777, 99.84],
    [1.823, 103.5],
    [1.864, 104.3],
    [1.893, 105.7],
    [1.913, 106.4],
    [1.950, 108.4],
    [1.986, 110.6],
    [2.020, 111.8],
    [2.040, 112.9],
    [2.077, 114.6],
    [2.106, 116.5],
    [2.127, 118.4],
    [2.163, 121.4],
    [2.192, 124.1],
    [2.213, 125.9],
    [2.249, 131.2],
    [2.276, 142.2],
    [2.240, 154.9],
    [2.199, 164.0],
    [2.158, 172.9],
    [2.118, 182.0],
    [2.077, 191.6],
    [2.036, 202.0],
    [1.995, 213.0],
    [1.954, 225.8],
    [1.914, 237.7],
    [1.873, 249.6],
    [1.832, 260.3],
    [1.796, 271.1],
    [1.775, 274.9],
    [1.746, 283.1],
    [1.705, 293.6],
    [1.660, 306.8],
    [1.628, 317.6],
    [1.608, 323.2],
    [1.578, 334.8],
    [1.542, 352.0],
    [1.501, 375.2],
    [1.465, 404.2],
    [1.438, 454.3],
    [1.449, 519.8],
    [1.488, 559.5],
    [1.520, 582.9],
    [1.497, 676.8],
    [1.472, 767.7],
    [1.449, 861.9],
    [1.418, 953.0],
]

# %%
x= [row[0] for row in FRANK]
y= [row[1] for row in FRANK]
import matplotlib.pyplot as plt
plt.figure(figsize=(5, 8))
plt.plot(x,y)
plt.yscale('log')
plt.gca().invert_yaxis()
plt.show()

# %%
from ambiance import Atmosphere
from scipy.interpolate import interp1d
import numpy as np
delta_h = 100.0  # height increment in meters
delta_deg = 1.0  # latitude increment
heights = np.arange(0, 60000 + delta_h, delta_h)  # 0 to 60 km

latitudes = np.arange(
    -85, 85, delta_deg)
plev = Atmosphere(heights).pressure/100

f = interp1d(y, x, kind='linear', fill_value="extrapolate")

# Compute interpolated values
new_yields = f(plev)

plt.figure(figsize=(5, 8))
plt.plot(new_yields,plev)
plt.yscale('log')
plt.xlim([0,2.4])
plt.ylim([0.01,1000])
plt.gca().invert_yaxis()
plt.show()

# %%
from openairclim.calc_swv import *
M_h2o = 18.01528 * 10**-3  # kg/mol
M_air = 28.97 * 10**-3  # kg/mol
def calc_swv_mass_conc(delta_ch4, display_distribution=False):
    """
    Calculates the SWV concentration and mass based on the oxidation of CH4. It is based on the tropospheric CH4 change, the fractional release factor, and the Age-of-Air.
    Based on the papers of Austin 2007, Hegglin 2014 and Harmsen 2026 #TODO make the citations correct

    Args:
        delta_ch4 (list): List of yearly changes in CH4 concentration due to an emission.
        alpha (np.ndarray): The fractional release factor of CH4, based on altitude and latitude.
        AoA: (np.ndarray): The age-of-air based on altitude and latitude rounded to the nearest integer year.

    Returns:
        delta_mass_swv (list): A list of the total change in SWV mass in Tg due to CH4 oxidation for each year corresponding to delta_ch4.
        delta_conc_swv (list): A list with the average stratospheric concentration change of SWV in ppbv due to CH4 oxidation for each year corresponding to delta_ch4.
    """
    # initialize
    delta_mass_swv = np.ones(len(delta_ch4))
    delta_conc_swv = np.ones(len(delta_ch4))

    # define constants
    delta_h = 100.0  # height increment in meters
    delta_deg = 1.0  # latitude increment
    heights = np.arange(0, 60000 + delta_h, delta_h)  # 0 to 60 km

    latitudes = np.arange(
        -85, 85, delta_deg
    )  # -85° to 85° #TODO verify these numbers, justify the values,
    # TODO this gives sometimes a non 0 in the first year, why?
    # TODO probably due to the extrpolating of the grid introducing tropospheric values

    volume = get_volume_matrix(heights, latitudes, delta_h, delta_deg)
    density = Atmosphere(heights).density
    mass_mat = volume * density[:, np.newaxis]  # kg
    alpha, AoA = get_alpha_AOA(heights, latitudes, plot_data=False)

    for t in range(len(delta_ch4)):
        # get swv distribution
        multiplier_map = {
            1: delta_ch4[t - 1] if t - 1 >= 0 else 0.0,
            2: delta_ch4[t - 2] if t - 2 >= 0 else 0.0,
            3: delta_ch4[t - 3] if t - 3 >= 0 else 0.0,
            4: delta_ch4[t - 4] if t - 4 >= 0 else 0.0,
            5: delta_ch4[t - 5] if t - 5 >= 0 else 0.0,
        }
        df_ch4_lagged = AoA.replace(multiplier_map)
        # h2o_yield = new_yields
        swv = alpha * df_ch4_lagged * new_yields[:, np.newaxis]  # ppbv
        other_distribution = alpha * df_ch4_lagged * 2  # ppbv

        # calculate average concentration
        number_density = Atmosphere(heights).number_density
        swv_parts_mat = volume * number_density[:, np.newaxis] * swv * 1e-9
        tot_parts = np.nansum(
            (
                volume
                * np.where(np.isnan(swv_parts_mat), np.nan, 1)
                * number_density[:, np.newaxis]
            )
        )  # to make sure only stratospheric volume is taken
        average_conc = np.nansum(swv_parts_mat) / tot_parts * 1e9  # ppbv

        # calculate total swv mass
        SWV_mass_mat = swv * 10**-9 * M_h2o / M_air * mass_mat  # kg
        swv_mass = np.nansum(SWV_mass_mat) / 1e9  # Tg
        # print(swv_mass)

        # store data
        delta_mass_swv[t] = swv_mass  # Tg
        delta_conc_swv[t] = average_conc  # ppbv
    final_swv_distribution = swv
    difference = final_swv_distribution - other_distribution
    return delta_mass_swv, delta_conc_swv, final_swv_distribution,difference,SWV_mass_mat, difference* 10**-9 * M_h2o / M_air * mass_mat

# %%
m,c,d,diff, m_d, m_d_diff = calc_swv_mass_conc([100,100,100,100,100,100,100])

# %%
plt.figure(figsize=(10, 6))
# X, Y = (len(grid[0, :]), len(grid[:, 0]))
heatmap = plt.pcolormesh(
    latitudes,
    Atmosphere(heights).pressure / 100,  # make it hPa
    diff,
    shading="auto",
    cmap="viridis",
)
plt.colorbar(heatmap, label="Value")
plt.yscale("log")
plt.gca().invert_yaxis()  # invert so low pressure is at the top
plt.xlabel("Latitude (deg)")
plt.ylabel("Altitude (hPa)")
plt.title("difference due to yield change [ppbv SWV]")
plt.tight_layout()
plt.show()


plt.figure(figsize=(10, 6))
# X, Y = (len(grid[0, :]), len(grid[:, 0]))
heatmap = plt.pcolormesh(
    latitudes,
    Atmosphere(heights).pressure / 100,  # make it hPa
    d,
    shading="auto",
    cmap="viridis",
)
plt.colorbar(heatmap, label="Value")
plt.yscale("log")
plt.gca().invert_yaxis()  # invert so low pressure is at the top
plt.xlabel("Latitude (deg)")
plt.ylabel("Altitude (hPa)")
plt.title("SWv with y=2 [ppbv SWV]")
plt.tight_layout()
plt.show()

# %%
np.nansum(diff)
# Out:
# np.float64(-103577.9879436592)

# %%
plt.figure(figsize=(10, 6))
# X, Y = (len(grid[0, :]), len(grid[:, 0]))
heatmap = plt.pcolormesh(
    latitudes,
    Atmosphere(heights).pressure / 100,  # make it hPa
    m_d_diff,
    shading="auto",
    cmap="viridis",
)
plt.colorbar(heatmap, label="Value")
plt.yscale("log")
plt.gca().invert_yaxis()  # invert so low pressure is at the top
plt.xlabel("Latitude (deg)")
plt.ylabel("Altitude (hPa)")
plt.title("difference due to yield change [kg SWV]")
plt.tight_layout()
plt.show()


plt.figure(figsize=(10, 6))
# X, Y = (len(grid[0, :]), len(grid[:, 0]))
heatmap = plt.pcolormesh(
    latitudes,
    Atmosphere(heights).pressure / 100,  # make it hPa
    m_d,
    shading="auto",
    cmap="viridis",
)
plt.colorbar(heatmap, label="Value")
plt.yscale("log")
plt.gca().invert_yaxis()  # invert so low pressure is at the top
plt.xlabel("Latitude (deg)")
plt.ylabel("Altitude (hPa)")
plt.title("SWv with y=2 [kg SWV]")
plt.tight_layout()
plt.show()

# %%
np.nansum(m_d_diff)/1e9
# Out:
# np.float64(-3.1625099171465947)

# %%
np.nansum(m_d) / 1e9
m
# Out:
# array([ 0.        ,  1.74585706,  6.38977985, 12.33034032, 20.13210074,
#        20.13210074, 20.13210074])

# %%
# SO including FRANK will give a decrease on SWV mass of 3 tg on an before estimated mass of 23 tg so it becomes 20 tg

# %%
ch4_historic = [1729.33056640625,
1740.139282226562,
1743.100708007812,
1748.620361328125,
1755.229614257812,
1757.190551757812,
1761.501098632812,
1770.290649414062,
1778.199462890625]

def calc_alpha(heights, latitudes, tp_value = 1.778):
    # tp_value = 1.778  # TODO evaluate this number
    df = construct_myhre_1m_df(tropopause_value=tp_value, cp_lat=87, cp_a=80)
    grid = get_griddata(df, heights, latitudes, plot_data=False)
    ### This grid will resemble the HAlOE CH4 concentrtion (ppmv)data of myhre fig 1

    ch4_e = tp_value  # ppmv # TODO
    alpha = (ch4_e - grid) / ch4_e

    aoa = 0.3 + 15.2 * alpha - 21.2 * alpha**2 + 10.4 * alpha**3

    AoA = pd.DataFrame(aoa.round(0))
    return alpha, AoA

M_h2o = 18.01528 * 10**-3  # kg/mol
M_air = 28.97 * 10**-3  # kg/mol
def calc_swv_mass_conc_tpdep(delta_ch4, tp_value, display_distribution=False):
    """
    Calculates the SWV concentration and mass based on the oxidation of CH4. It is based on the tropospheric CH4 change, the fractional release factor, and the Age-of-Air.
    Based on the papers of Austin 2007, Hegglin 2014 and Harmsen 2026 #TODO make the citations correct

    Args:
        delta_ch4 (list): List of yearly changes in CH4 concentration due to an emission.
        alpha (np.ndarray): The fractional release factor of CH4, based on altitude and latitude.
        AoA: (np.ndarray): The age-of-air based on altitude and latitude rounded to the nearest integer year.

    Returns:
        delta_mass_swv (list): A list of the total change in SWV mass in Tg due to CH4 oxidation for each year corresponding to delta_ch4.
        delta_conc_swv (list): A list with the average stratospheric concentration change of SWV in ppbv due to CH4 oxidation for each year corresponding to delta_ch4.
    """
    # initialize
    delta_mass_swv = np.ones(len(delta_ch4))
    delta_conc_swv = np.ones(len(delta_ch4))

    # define constants
    delta_h = 100.0  # height increment in meters
    delta_deg = 1.0  # latitude increment
    heights = np.arange(0, 60000 + delta_h, delta_h)  # 0 to 60 km

    latitudes = np.arange(
        -85, 85, delta_deg
    )  # -85° to 85° #TODO verify these numbers, justify the values,
    # TODO this gives sometimes a non 0 in the first year, why?
    # TODO probably due to the extrpolating of the grid introducing tropospheric values

    volume = get_volume_matrix(heights, latitudes, delta_h, delta_deg)
    density = Atmosphere(heights).density
    mass_mat = volume * density[:, np.newaxis]  # kg
    alpha, AoA = calc_alpha(heights, latitudes, tp_value=tp_value)

    for t in range(len(delta_ch4)):
        # get swv distribution
        multiplier_map = {
            1: delta_ch4[t - 1] if t - 1 >= 0 else 0.0,
            2: delta_ch4[t - 2] if t - 2 >= 0 else 0.0,
            3: delta_ch4[t - 3] if t - 3 >= 0 else 0.0,
            4: delta_ch4[t - 4] if t - 4 >= 0 else 0.0,
            5: delta_ch4[t - 5] if t - 5 >= 0 else 0.0,
        }
        df_ch4_lagged = AoA.replace(multiplier_map)
        # h2o_yield = new_yields
        swv = alpha * df_ch4_lagged * new_yields[:, np.newaxis]  # ppbv
        other_distribution = alpha * df_ch4_lagged * 2  # ppbv

        # calculate average concentration
        number_density = Atmosphere(heights).number_density
        swv_parts_mat = volume * number_density[:, np.newaxis] * swv * 1e-9
        tot_parts = np.nansum(
            (
                volume
                * np.where(np.isnan(swv_parts_mat), np.nan, 1)
                * number_density[:, np.newaxis]
            )
        )  # to make sure only stratospheric volume is taken
        average_conc = np.nansum(swv_parts_mat) / tot_parts * 1e9  # ppbv

        # calculate total swv mass
        SWV_mass_mat = swv * 10**-9 * M_h2o / M_air * mass_mat  # kg
        swv_mass = np.nansum(SWV_mass_mat) / 1e9  # Tg
        # print(swv_mass)

        # store data
        delta_mass_swv[t] = swv_mass  # Tg
        delta_conc_swv[t] = average_conc  # ppbv
    final_swv_distribution = swv
    difference = final_swv_distribution - other_distribution
    return delta_mass_swv, delta_conc_swv, final_swv_distribution,difference,SWV_mass_mat, difference* 10**-9 * M_h2o / M_air * mass_mat

for tp_value in ch4_historic:
    m,c,d,diff, m_d, m_d_diff = calc_swv_mass_conc_tpdep([100,100,100,100,100,100,100], tp_value)
    print('mass = ', m[-1], 'tp_value' ,tp_value)
# Out:
# mass =  89.45299200291147 tp_value 1729.33056640625
# mass =  89.45343482767815 tp_value 1740.139282226562
# mass =  89.45355519655138 tp_value 1743.100708007812
# mass =  89.453778457941 tp_value 1748.620361328125
# mass =  89.45404394462066 tp_value 1755.229614257812
# mass =  89.45412232922804 tp_value 1757.190551757812
# mass =  89.45429402137322 tp_value 1761.501098632812
# mass =  89.4546415247414 tp_value 1770.290649414062
# mass =  89.45495127103304 tp_value 1778.199462890625
